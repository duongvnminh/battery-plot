# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

file_name = 'capacity vs scan rate_1'
data = pd.read_excel(f'{file_name}.xlsx')
data.head()
# Out:
#    0          1         2     3   4          5         6          7   \
# 0   1  37.133333  0.569600  43.8 NaN  33.600000  2.107131  31.078836
# 1   5  25.566667  0.993870  32.0 NaN  28.333333  2.380710  21.049206
# 2  10  20.600000  1.159023  27.0 NaN  25.333333  2.493547  17.492063
# 3  25  14.700000  1.193035  20.8 NaN  20.800000  2.433105  13.705291
# 4  50  10.433333  1.071344  15.3 NaN  17.033333  1.705221  10.697884
#
#          8          9         10
# 0  0.873461  14.166667  2.086731
# 1  1.462616   5.122222  0.789827
# 2  1.413899   3.355556  0.576173
# 3  1.018286   2.211111  0.397368
# 4  0.584323   1.744444  0.331290

# %%
fig, ax = plt.subplots(figsize=(10.7, 8.2), dpi=150)
legend = ['FTO_RT', 'FTO_60', 'FTO_200', 'FTO_200_air', 'FTO_300_air']
c = 0.1

for i in range(0, len(legend)*2 - 1, 2):
    c +=0.25
    ax.errorbar(np.array(data.iloc[:, 0]),
                np.array(data.iloc[:, i+1]),
                yerr = np.array(data.iloc[:, i+2]),
                label = legend[int(i/2)],
                linewidth = 4,
                marker = 'o'
               )

print('Number of lines: ', len(ax.lines)) 

colormap = plt.cm.gist_ncar  
colors = [colormap(i) for i in np.linspace(0, 1, len(ax.lines)/2.7 + 5)]  #change here

for i,j in enumerate(ax.lines):
    j.set_color(colors[i])

ax.legend(loc = 'upper right', fontsize = 16)
plt.ylabel('Cathodic capacity (mAh/g)', fontsize = 30, weight = 'bold')
plt.xlabel('scan rate (mV/s)', fontsize = 30, weight = 'bold')

#plt.text(0.03, 1100, file_name, fontsize = 22, color = 'red')

ax.xaxis.set_tick_params(labelsize=26)
ax.yaxis.set_tick_params(labelsize=26)
plt.minorticks_on()

ax.set_ylim(-2, 50)
#ax.set_xlim(0, 110)
            
ax.spines["bottom"].set_linewidth(2)
ax.spines["top"].set_linewidth(2)
ax.spines["right"].set_linewidth(2)
ax.spines["left"].set_linewidth(2)

#plt.savefig(f'CV_{file_name}.tif', bbox_inches = 'tight')

plt.show()
# Out:
# Number of lines:  5
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
