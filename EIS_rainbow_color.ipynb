# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

file_name = 'EIS'
data = pd.read_excel(f'{file_name}.xlsx')
data.head()
# Out:
#           1         2          3         4          5         6          7   \
# 0  82.367523  0.725715  37.874416  0.172263  36.430969  0.064580  26.496805
# 1  82.333031  0.676154  37.902355  0.195359  36.463501  0.105319  26.517488
# 2  82.646568  0.728206  37.947266  0.214416  36.494999  0.159411  26.534060
# 3  82.946991  0.693023  37.981335  0.224178  36.529526  0.201804  26.591633
# 4  82.828941  0.682378  38.018898  0.241375  36.554428  0.236767  26.598680
#
#          8          9         10         11         12
# 0  0.106933  34.066357 -0.041149  38.446281  14.967351
# 1  0.108671  34.089241  0.001414  40.845280  17.314896
# 2  0.159763  34.115101  0.058193  43.902325  19.750549
# 3  0.188867  34.131390  0.087880  47.692787  21.983194
# 4  0.214999  34.157265  0.133089  52.210083  23.741058

# %%
fig, ax = plt.subplots(figsize= (10.7, 8.2), dpi=150)
label = ['FTO_blank', 'FTO_RT', 'FTO_60', 'FTO_200', 'FTO_200_air', 'FTO_300_air']
c = 0.1

for i in range(0, len(label)*2 - 1, 2):
    c +=0.25
    ax.plot(np.array(data.iloc[:, i]),
            np.array(data.iloc[:, i+1]),
            linewidth = 2,
            label = label[int(i/2)],
           marker = 'o')

print(len(ax.lines))    
colormap = plt.cm.gist_ncar  
colors = [colormap(i) for i in np.linspace(0, 1, len(ax.lines)/2.7 + 5)]  #change here

for i,j in enumerate(ax.lines):
    j.set_color(colors[i])
    
#ax.legend(loc = 'upper right', fontsize = 14)
plt.ylabel('-Z" (Ω)', fontsize = 30, weight = 'bold')
plt.xlabel("Z' (Ω)", fontsize = 30, weight = 'bold')

#plt.text(0.03, 1100, file_name, fontsize = 22, color = 'red')

ax.xaxis.set_tick_params(labelsize=26)
ax.yaxis.set_tick_params(labelsize=26)
plt.minorticks_on()
ax.set_ylim(0, 120)
ax.set_xlim(0, 160)

ax.spines["bottom"].set_linewidth(2)
ax.spines["top"].set_linewidth(2)
ax.spines["right"].set_linewidth(2)
ax.spines["left"].set_linewidth(2)

plt.savefig(f'CV_{file_name}_zoom.tif', bbox_inches = 'tight')

plt.show()
# Out:
# 6
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   from ipykernel import kernelapp as app
